# %%
# !pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 24.1.2 -> 24.2
# [notice] To update, run: /opt/homebrew/opt/python@3.11/bin/python3.11 -m pip install --upgrade pip

# %%
import pandas as pd

# %%
filename = 'WLASL_v0.3.json'
df = pd.read_json(filename)

print(df.head())
print(df.shape)
# Out:
#       gloss                                          instances
# 0      book  [{'bbox': [385, 37, 885, 720], 'fps': 25, 'fra...
# 1     drink  [{'bbox': [551, 68, 1350, 1080], 'fps': 25, 'f...
# 2  computer  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 3    before  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 4     chair  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# (2000, 2)

# %%
'jump' in unique_words
# Out:
# True

# %%
unique_words = df.gloss.unique()
len(unique_words)
# Out:
# 2000

# %%
import json 
with open('obama.json', 'r') as f:
    data = json.load(f)

print(m)
# Out:
# {'metadata': {'transaction_key': 'deprecated', 'request_id': 'e0dd5846-78d1-4e7f-be1d-ceb01ec686d1', 'sha256': '92632a4d60753c96935d8d8206ed4b81d835f0e14809740f0f61dbfdc1966ade', 'created': '2024-08-03T19:30:45.565Z', 'duration': 425.0645, 'channels': 1, 'models': ['1ed36bac-f71c-4f3f-a31f-02fd6525c489'], 'model_info': {'1ed36bac-f71c-4f3f-a31f-02fd6525c489': {'name': 'general', 'version': '2024-01-26.8851', 'arch': 'base'}}}, 'results': {'channels': [{'alternatives': [{'transcript': "Now ready to go some simone bile. Your chin double pike. Big gets step back at the end, but she just needed to put it on our feet because that bolt has such a high difficulty value she can afford a big step. And I don't know parents watkins on husbands safety for the repairs, away from training camp, Teammates hanging on every movement. Sister Adrian Team t shirts. Oh, okay then. Fifteen seven six six. What? That is incredible. Exactly how Simon simone wanted to start this competition She's been through
# ...

# %%
data['results']['channels'][0]['alternatives'][0]['transcript']
# Out:
# "It is that fundamental belief. I am my brother's keeper. I am my sister's keeper that makes this country work. It's what allows us to pursue our individual dreams and yet still come together as one American family. E p un out of many one. Now, even as we speak, there are those who are preparing to divide. The spin masters, the negative ad peddle who embrace the politics of anything goes. Well, I say to them tonight, there is not a liberal America and a conservative America. There is the United States of America. There is not a black America and a white America and Latino America and Asian America There's the United States of America. The pun, the pun like to slice and dice our country. Into red states and blue states, red states for Republicans, blue states for Democrats, but I've got news for them too. We worship an awesome god. In the blue states, and we don't like federal agents poking around in our libraries in the red states. We coach little league in the blue states. And, yes,
# ...

# %%
words = data['results']['channels'][0]['alternatives'][0]['words']

# Create a list of tuples with word and timestamps
parsed_words = [(word_info['word'], word_info['start'], word_info['end']) for word_info in words]

# Display the list of words and timestamps
in_unique_words = 0
not_in_unique_words = 0

for word, start, end in parsed_words:
    word_lower = word.lower().strip()
    if word_lower in unique_words:
        tag = "Yes"
        in_unique_words += 1
    else:
        tag = "No"
        not_in_unique_words += 1
    print(f"Word: {word}, Start: {start}, End: {end}, Tag: {tag}")

print(f"\nWords in unique words list: {in_unique_words}")
print(f"Words not in unique words list: {not_in_unique_words}")
# Out:
# Word: now, Start: 1.4749545, End: 1.9749545, Tag: Yes
# Word: ready, Start: 2.1924999, End: 2.511409, Tag: Yes
# Word: to, Start: 2.511409, End: 2.6708636, Tag: Yes
# Word: go, Start: 2.6708636, End: 3.1708636, Tag: Yes
# Word: some, Start: 3.7870452, End: 3.9464998, Tag: Yes
# Word: simone, Start: 3.9464998, End: 4.185682, Tag: No
# Word: bile, Start: 4.185682, End: 4.5045905, Tag: No
# Word: your, Start: 9.223366, End: 9.462475, Tag: Yes
# Word: chin, Start: 9.462475, End: 9.940693, Tag: No
# Word: double, Start: 9.940693, End: 10.339208, Tag: Yes
# Word: pike, Start: 10.339208, End: 10.578317, Tag: No
# Word: big, Start: 14.005545, End: 14.324356, Tag: Yes
# Word: gets, Start: 14.324356, End: 14.6431675, Tag: No
# Word: step, Start: 14.6431675, End: 14.96198, Tag: No
# Word: back, Start: 14.96198, End: 15.46198, Tag: Yes
# Word: at, Start: 15.838713, End: 15.998118, Tag: No
# Word: the, Start: 15.998118, End: 16.237226, Tag: No
# ...

# %%
for i in unique_words:
    print(i)
# Out:
# book
# drink
# computer
# before
# chair
# go
# clothes
# who
# candy
# cousin
# deaf
# fine
# help
# no
# thin
# walk
# year
# yes
# all
# black
# cool
# finish
# hot
# like
# many
# mother
# now
# orange
# table
# thanksgiving
# what
# woman
# bed
# blue
# bowling
# can
# dog
# family
# fish
# graduate
# hat
# hearing
# kiss
# language
# later
# man
# shirt
# study
# tall
# white
# wrong
# accident
# apple
# bird
# change
# color
# corn
# cow
# dance
# dark
# doctor
# eat
# enjoy
# forget
# give
# last
# meet
# pink
# pizza
# play
# school
# secretary
# short
# time
# want
# work
# africa
# basketball
# birthday
# brown
# but
# cheat
# city
# cook
# decide
# full
# how
# jacket
# letter
# medicine
# need
# paint
# paper
# pull
# purple
# right
# same
# son
# tell
# thursday
# visit
# wait
# water
# wife
# yellow
# backpack
# bar
# brother
# cat
# check
# class
# cry
# different
# door
# green
# hair
# have
# headache
# inform
# knife
# laugh
# learn
# movie
# rabbit
# read
# red
# ...

# %%
data = {
"original": "It is that fundamental belief. I am my brother's keeper. I am my sister's keeper that makes this country work. It's what allows us to pursue our individual dreams and yet still come together as one American family. E p un out of many one. Now, even as we speak, there are those who are preparing to divide. The spin masters, the negative ad peddle who embrace the politics of anything goes. Well, I say to them tonight, there is not a liberal America and a conservative America. There is the United States of America. There is not a black America and a white America and Latino America and Asian America There's the United States of America. The pun, the pun like to slice and dice our country. Into red states and blue states, red states for Republicans, blue states for Democrats, but I've got news for them too. We worship an awesome god. In the blue states, and we don't like federal agents poking around in our libraries in the red states. We coach little league in the blue states. And, yes, we've got some gay friends in the red states. There are patriots who oppose the war in a iraq. And their patriots who supported the war in iraq. We are one people, All of us pledging allegiance to the stars and stripes. All of us defending the United States of America.",
"new_sentences": [
"It is that fundamental belief.",
"I am my brother's keeper.",
"I am my sister's keeper that makes this country work.",
"It's what allows us to pursue our individual dreams and yet still come together as one American family.",
"E p un out of many one.",
"Now, even as we speak, there are those who are preparing to divide.",
"The spin masters, the negative ad peddle who embrace the politics of anything goes.",
"Well, I say to them tonight, there is not a liberal America and a conservative America.",
"There is the United States of America.",
"There is not a black America and a white America and Latino America and Asian America",
"There's the United States of America.",
"The pun, the pun like to slice and dice our country.",
"Into red states and blue states, red states for Republicans, blue states for Democrats, but I've got news for them too.",
"We worship an awesome god.",
"In the blue states, and we don't like federal agents poking around in our libraries in the red states.",
"We coach little league in the blue states.",
"And, yes, we've got some gay friends in the red states.",
"There are patriots who oppose the war in a iraq.",
"And their patriots who supported the war in iraq.",
"We are one people, All of us pledging allegiance to the stars and stripes.",
"All of us defending the United States of America."
],
"gloss": [
[
"it",
"that",
"belief",
"fundamental"
],
[
"i",
"be",
"brother",
"keeper"
],
[
"i",
"be",
"sister",
"keeper",
"that",
"make",
"country",
"work"
],
[
"it",
"be",
"what",
"allow",
"we",
"pursue",
"dream",
"individual",
"and",
"yet",
"still",
"come",
"together",
"as",
"one",
"american",
"family"
],
[
"e",
"p",
"un",
"out",
"of",
"many",
"one"
],
[
"now",
"even",
"as",
"we",
"speak",
"there",
"be",
"those",
"who",
"be",
"prepare",
"to",
"divide"
],
[
"the",
"spin",
"master",
"the",
"negative",
"ad",
"peddle",
"who",
"embrace",
"the",
"politics",
"of",
"anything",
"go"
],
[
"well",
"i",
"say",
"to",
"them",
"tonight",
"there",
"be",
"not",
"a",
"liberal",
"america",
"and",
"a",
"conservative",
"america"
],
[
"there",
"be",
"the",
"united",
"states",
"of",
"america"
],
[
"there",
"be",
"not",
"a",
"black",
"america",
"and",
"a",
"white",
"america",
"and",
"latino",
"america",
"and",
"asian",
"america"
],
[
"there",
"be",
"the",
"united",
"states",
"of",
"america"
],
[
"the",
"pun",
"the",
"pun",
"like",
"to",
"slice",
"and",
"dice",
"our",
"country"
],
[
"into",
"red",
"state",
"and",
"blue",
"state",
"red",
"state",
"for",
"republican",
"blue",
"state",
"for",
"democrat",
"but",
"i",
"have",
"got",
"news",
"for",
"them",
"too"
],
[
"we",
"worship",
"an",
"awesome",
"god"
],
[
"in",
"the",
"blue",
"state",
"and",
"we",
"not",
"like",
"federal",
"agent",
"poke",
"around",
"in",
"our",
"library",
"in",
"the",
"red",
"state"
],
[
"we",
"coach",
"little",
"league",
"in",
"the",
"blue",
"state"
],
[
"and",
"yes",
"we",
"have",
"got",
"some",
"gay",
"friend",
"in",
"the",
"red",
"state"
],
[
"there",
"be",
"patriot",
"who",
"oppose",
"the",
"war",
"in",
"a",
"iraq"
],
[
"and",
"their",
"patriot",
"who",
"support",
"the",
"war",
"in",
"iraq"
],
[
"we",
"be",
"one",
"people",
"all",
"of",
"we",
"pledge",
"allegiance",
"to",
"the",
"star",
"and",
"stripe"
],
[
"all",
"of",
"we",
"defend",
"the",
"united",
"states",
"of",
"america"
]
]
}

# %%
for sentence in data['gloss']:
    print(sentence)
    for token in sentence:
        print(token)
        row = df.loc[df['gloss'] == token]
        print(row)
        break
    break
# Out:
# ['it', 'that', 'belief', 'fundamental']
# it
# Empty DataFrame
# Columns: [gloss, instances]
# Index: []

# %%
df
# Out:
#            gloss                                          instances
# 0           book  [{'bbox': [385, 37, 885, 720], 'fps': 25, 'fra...
# 1          drink  [{'bbox': [551, 68, 1350, 1080], 'fps': 25, 'f...
# 2       computer  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 3         before  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 4          chair  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# ...          ...                                                ...
# 1995  washington  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 1996   waterfall  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 1997       weigh  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
# 1998  wheelchair  [{'bbox': [415, 86, 1811, 1080], 'fps': 25, 'f...
# 1999     whistle  [{'bbox': [0, 0, 360, 240], 'fps': 25, 'frame_...
#
# [2000 rows x 2 columns]

# %%
'it' in df.gloss.tolist()
# Out:
# False
